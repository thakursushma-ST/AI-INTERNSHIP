# %% [markdown]
# ## hello world

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ## My intro

# %%
Name="Sushma Thakur"
Course="B.tech"
day=1
print(f"Name :{Name}")
print(f"Course :{Course}")
print(f"Day :{day}")
# Out:
# Name :Sushma Thakur
# Course :B.tech
# Day :1
